# %%
import os
from os.path import join
from io import StringIO
from textwrap import dedent

import sympy
from sympy import Symbol, sqrt, cos, pi, symbols
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
from collections import defaultdict

import qnet
from qnet.algebra import *

import QDYN

from src.notebook_plots_v1 import plot_bs_decay, display_hamiltonian, display_eq, show_summary_dicke
from src.single_sided_network_v1 import network_slh
from src.dicke_single_model_v1 import write_dicke_single_model, err_dicke_single

from doit.tools import register_doit_as_IPython_magic
import clusterjob

# %%
qnet.init_printing()

# %%
DOIT_CONFIG = {
    'backend': 'json',
    'dep_file': '.doit_db/2017-06-01_mg_dicke1_QSL_traj1.json',
}
register_doit_as_IPython_magic()

# %%
clusterjob.JobScript.read_defaults('./config/mlhpc_cluster.ini')

# %% [markdown]
# $
# \newcommand{ket}[1]{\vert #1 \rangle}
# \newcommand{bra}[1]{\langle #1 \vert}
# \newcommand{Op}[1]{\hat{#1}}
# $
#
# # QSL for Single-Excitation Dicke state
#
# ## action wrappers

# %%
def update_config(rf, lambda_a, iter_stop):
    config = QDYN.config.read_config_file(join(rf, 'config'))
    config['oct']['iter_stop'] = iter_stop
    for pulse_config in config['pulse']:
        pulse_config['oct_lambda_a'] = lambda_a
    QDYN.config.write_config(config, join(rf, 'config'))

# %%
def submit_optimization(rf, n_trajs, task):
    """Asynchronously run optimization"""
    if os.path.isfile(join(rf, 'oct.job.dump')):
        return
    body = dedent(r'''
    {module_load}

    cd $CLUSTERJOB_WORKDIR
    pwd
    OMP_NUM_THREADS=1 {runner} qdyn_optimize --n-trajs={n_trajs} \
         --J_T=J_T_sm .
    ''')
    taskname = "oct_%s" % task.name.split(":")[-1]
    jobscript = clusterjob.JobScript(
        body=body, jobname=taskname, workdir=rf,
        stdout='oct.log')
    runner = {
        'copper': 'aprun -B',
        'mlhpc': 'mpirun -n %d' % n_trajs}
    if jobscript.cluster_name != 'copper':
        jobscript.ppn = int(n_trajs)
        if n_trajs == 1:
            runner['mlhpc'] = ''
    jobscript.runner = runner[jobscript.cluster_name]
    jobscript.n_trajs = str(int(n_trajs))
    run = jobscript.submit(cache_id=taskname)
    run.dump(join(rf, 'oct.job.dump'))

# %%
def wait_for_clusterjob(dumpfile):
    """Wait until the clusterjob.AsyncResult cached in the given dumpfile ends"""
    try:
        run = clusterjob.AsyncResult.load(dumpfile)
        run.wait()
        os.unlink(dumpfile)
        return run.successful()
    except OSError:
        pass

# %% [markdown]
# ## custom uptodate routines

# %%
from src.qdyn_model_v1 import pulses_uptodate

# %% [markdown]
# ## task definitions

# %%
def runfolder(row):
    int_part, frac_part = ("%.2f" % row['T']).split('.')
    root = './data/dicke1_QSL_1traj/'
    if frac_part == '00':
        rf = 'rf_%dnodes_T%s' % (row['n_nodes'], int_part)
    else:
        rf = 'rf_%dnodes_T%s_%s' % (row['n_nodes'], int_part, frac_part)
    return join(root, rf)

# %%
def task_create_runfolder():
    """Create all necessary runfolders for the runs defined in params_df"""
    jobs = {}
    slh_models = {}
    for ind, row in params_df.iterrows():
        rf = runfolder(row)
        n_nodes = int(row['n_nodes'])
        try:
            slh = slh_models[n_nodes]
        except KeyError:
            slh = network_slh(
                n_cavity=2, n_nodes=n_nodes, topology='driven_bs_fb')
            slh_models[n_nodes] = slh
        if n_nodes not in slh_models:
            slh_mode
        if rf in jobs:
            continue
        jobs[rf] = {
            'name': str(rf),
            'actions': [
                (write_dicke_single_model, [slh, ], dict(
                    rf=rf, T=row['T'], theta=0, nt=500,
                    kappa=1.0, E0_cycles=2, mcwf=True, non_herm=True,
                    lambda_a=row['lambda_a'],
                    iter_stop=int(row['iter_stop'])))],
            'targets': [join(rf, 'config')],
            'uptodate': [True, ] # up to date if target exists
        }
    for job in jobs.values():
        yield job

# %%
def task_update_runfolder():
    """For every row in params_df, update the config file in the appropriate
    runfolder with the value in that row"""
    rf_jobs = defaultdict(list)
    for ind, row in params_df.iterrows():
        rf = runfolder(row)
        # we only update the config after any earlier optimization has finished
        task_dep = ['wait_for_optimization:%s' % ind2 for ind2 in rf_jobs[rf]]
        rf_jobs[rf].append(ind)
        yield {
            'name': str(ind),
            'actions': [
                (update_config, [], dict(
                    rf=rf, lambda_a=row['lambda_a'],
                    iter_stop=int(row['iter_stop'])))],
            'file_dep': [join(rf, 'config')],
            'uptodate': [False, ],  # always run task
            'task_dep': task_dep}

# %%
def task_submit_optimization():
    """Run optimization for every runfolder from params_df"""
    rf_jobs = defaultdict(list)
    for ind, row in params_df.iterrows():
        rf = runfolder(row)
        task_dep = ['wait_for_optimization:%s' % ind2 for ind2 in rf_jobs[rf]]
        task_dep.append('update_runfolder:%s' % ind)
        yield {
            'name': str(ind),
            'actions': [
                (submit_optimization, [rf, ], dict(n_trajs=row['n_trajs']))],
                # 'task' keyword arg is added automatically
            'task_dep': task_dep,
            'uptodate': [(pulses_uptodate, [], {'rf': rf}), ],
        }

# %%
def task_wait_for_optimization():
    for ind, row in params_df.iterrows():
        rf = runfolder(row)
        yield {
            'name': str(ind),
            'task_dep': ['submit_optimization:%d' % ind],
            'actions': [
                (wait_for_clusterjob, [join(rf, 'oct.job.dump')], {}),]}

# %% [markdown]
# ##  OCT Submission

# %%
params_data_str = r'''
# n_nodes   T     lambda_a  n_trajs   iter_stop
        2   1.00     0.001        1        1000
        2   1.00    0.0005        1       10000
        2   1.00    0.0005        1       15000
        2   2.00     0.001        1        1000
        2   2.00    0.0005        1       10000
        2   2.00    0.0005        1       15000
        2   3.00     0.001        1        1000
        2   3.00    0.0005        1       10000
        2   3.00    0.0005        1       15000
        2   4.00     0.001        1        1000
        2   4.00    0.0005        1       10000
        2   5.00     0.001        1        1000
        2   7.00     0.001        1        1000
        2  10.00     0.001        1        1000
        2  10.00    0.0005        1        2000
        2  20.00     0.001        1        1000
        2  50.00     0.001        1        1000
        2  50.00    0.0005        1        2000
        2  70.00     0.001        1        1000
        2  70.00    0.0005        1        2000
        3   1.00     0.001        1        1000
        3   1.00    0.0005        1       10000
        3   2.00     0.001        1        1000
        3   2.00    0.0005        1       10000
        3   3.00     0.001        1        1000
        3   3.00    0.0005        1       10000
        3   4.00     0.001        1        1000
        3   4.00    0.0005        1        4000
        3   5.00     0.001        1        1000
        3   5.00    0.0005        1        4000
        3   8.00     0.001        1        1000
        3   8.00    0.0005        1        2000
        3   9.00     0.001        1        1000
        3   9.00    0.0005        1        2000
        3  10.00     0.001        1        1000
        3  10.00    0.0005        1        2000
        3  15.00     0.001        1        1000
        3  20.00     0.001        1        1000
        3  50.00     0.001        1        1000
        3  50.00    0.0005        1        2000
        3  70.00     0.001        1        1000
        3  70.00    0.0005        1        2000
        4   0.50     0.001        1        1000
        4   1.00     0.001        1        1000
        4   1.00    0.0005        1       10000
        4   1.00    0.0005        1       15000
        4   2.00     0.001        1        1000
        4   2.00    0.0005        1       10000
        4   2.00    0.0005        1       15000
        4   3.00     0.001        1        1000
        4   3.00    0.0005        1       10000
        4   3.00    0.0005        1       15000
        4   4.00     0.001        1        1000
        4   4.00    0.0005        1       10000
        4   5.00     0.001        1        1000
        4   5.00    0.0005        1       10000
        4   6.00     0.001        1        1000
        4   6.00    0.0005        1       10000
        4   7.00     0.001        1        1000
        4   7.00    0.0005        1       10000
        4   8.00     0.001        1        1000
        4   8.00    0.0005        1        4000
        4   9.00     0.001        1        1000
        4   9.00    0.0005        1        4000
        4  10.00     0.001        1        1000
        4  10.00    0.0005        1        4000
        4  15.00     0.001        1        1000
        4  20.00     0.001        1        1000
        4  50.00     0.001        1        1000
        4  70.00     0.001        1        1000
        5   1.00     0.001        1        1000
        5   1.00    0.0005        1       10000
        5   1.00    0.0005        1       15000
        5   2.00     0.001        1        1000
        5   2.00    0.0005        1       10000
        5   2.00    0.0005        1       15000
        5   3.00     0.001        1        1000
        5   3.00    0.0005        1       10000
        5   3.00    0.0005        1       15000
        5   4.00     0.001        1        1000
        5   4.00    0.0005        1       10000
        5   4.00    0.0005        1       15000
        5   5.00     0.001        1        1000
        5   5.00    0.0005        1       10000
        5   5.00    0.0005        1       15000
        5   6.00     0.001        1        1000
        5   6.00    0.0005        1       10000
        5   7.00     0.001        1        1000
        5   7.00    0.0005        1       10000
        5   8.00     0.001        1        1000
        5   8.00    0.0005        1       10000
        5   9.00     0.001        1        1000
        5   9.00    0.0005        1       10000
        5   9.00    0.0005        1       20000
        5  10.00     0.001        1        1000
        5  10.00    0.0005        1        8000
        5  12.00     0.001        1        1000
        5  12.00    0.0005        1        2000
        5  15.00     0.001        1        1000
        5  15.00    0.0005        1        2000
        5  18.00     0.001        1        1000
        5  18.00    0.0005        1        2000
        5  20.00     0.001        1        1000
        5  20.00    0.0005        1        2000
        5  50.00     0.001        1        1000
        5  50.00    0.0005        1        2000
        5  70.00     0.001        1        1000
        5  70.00    0.0005        1        2000
        6   1.00     0.001        1        1000
        6   1.00    0.0005        1       10000
        6   2.00     0.001        1        1000
        6   2.00    0.0005        1       10000
        6   3.00     0.001        1        1000
        6   3.00    0.0005        1       10000
        6   4.00     0.001        1        1000
        6   4.00    0.0005        1       10000
        6   5.00     0.001        1        1000
        6   5.00    0.0005        1       10000
        6   5.00    0.0005        1       15000
        6   6.00    0.0005        1       10000
        6   6.00    0.0005        1       15000
        6   7.00    0.0005        1       10000
        6   7.00    0.0005        1       15000
        6   8.00     0.001        1        1000
        6   8.00    0.0005        1       10000
        6   8.00    0.0005        1       15000
        6   9.00     0.001        1        1000
        6   9.00    0.0005        1       10000
        6   9.00    0.0005        1       15000
        6  10.00     0.001        1        1000
        6  10.00    0.0005        1       10000
        6  12.00     0.001        1        1000
        6  12.00    0.0005        1       10000
        6  14.00     0.001        1        1000
        6  14.00    0.0005        1        5000
        6  14.00    0.0005        1       10000
        6  15.00     0.001        1        1000
        6  15.00    0.0005        1        2000
        6  18.00     0.001        1        1000
        6  18.00    0.0005        1        2000
        6  20.00     0.001        1        1000
        6  20.00    0.0005        1        2000
        6  50.00     0.001        1        1000
        6  50.00    0.0005        1        2000
        6  70.00     0.001        1        1000
        6  70.00    0.0005        1        2000
        7   5.00     0.001        1        1000
        7   5.00    0.0005        1       10000
        7   8.00     0.001        1        1000
        7   8.00    0.0005        1       10000
        7   9.00     0.001        1        1000
        7   9.00    0.0005        1       10000
        7  10.00     0.001        1        1000
        7  10.00    0.0005        1       10000
        7  12.00     0.001        1        1000
        7  12.00    0.0005        1       10000
        7  14.00     0.001        1        1000
        7  14.00    0.0005        1        5000
        7  14.00    0.0005        1       10000
        7  15.00     0.001        1        1000
        7  15.00    0.0005        1        2000
'''
params_df = pd.read_fwf(
        StringIO(params_data_str), comment='#', header=1,
        names=['n_nodes', 'T', 'lambda_a', 'n_trajs', 'iter_stop'],
        converters={'n_nodes': int, 'T': float, 'lambda_a': float,
                    'n_trajs': int, 'iter_stop': int})

# %%
print(params_df.to_string())
# Out:
#      n_nodes     T  lambda_a  n_trajs  iter_stop
# 0          2   1.0    0.0010        1       1000
# 1          2   1.0    0.0005        1      10000
# 2          2   1.0    0.0005        1      15000
# 3          2   2.0    0.0010        1       1000
# 4          2   2.0    0.0005        1      10000
# 5          2   2.0    0.0005        1      15000
# 6          2   3.0    0.0010        1       1000
# 7          2   3.0    0.0005        1      10000
# 8          2   3.0    0.0005        1      15000
# 9          2   4.0    0.0010        1       1000
# 10         2   4.0    0.0005        1      10000
# 11         2   5.0    0.0010        1       1000
# 12         2   7.0    0.0010        1       1000
# 13         2  10.0    0.0010        1       1000
# 14         2  10.0    0.0005        1       2000
# 15         2  20.0    0.0010        1       1000
# 16         2  50.0    0.0010        1       1000
# 17         2  50.0    0.0005        1       2000
# 18         2  70.0    0.0010        1       1000
# 19         2  70.0    0.0005        1       2000
# 20         3   1.0    0.0010        1       1000
# 21         3   1.0    0.0005        1      10000
# 22         3   2.0    0.0010        1       1000
# 23         3   2.0    0.0005        1      10000
# 24         3   3.0    0.0010        1       1000
# 25         3   3.0    0.0005        1      10000
# 26         3   4.0    0.0010        1       1000
# 27         3   4.0    0.0005        1       4000
# 28         3   5.0    0.0010        1       1000
# 29         3   5.0    0.0005        1       4000
# 30         3   8.0    0.0010        1       1000
# 31         3   8.0    0.0005        1       2000
# 32         3   9.0    0.0010        1       1000
# 33         3   9.0    0.0005        1       2000
# 34         3  10.0    0.0010        1       1000
# 35         3  10.0    0.0005        1       2000
# 36         3  15.0    0.0010        1       1000
# 37         3  20.0    0.0010        1       1000
# 38         3  50.0    0.0010        1       1000
# 39         3  50.0    0.0005        1       2000
# 40         3  70.0    0.0010        1       1000
# 41         3  70.0    0.0005        1       2000
# 42         4   0.5    0.0010        1       1000
# 43         4   1.0    0.0010        1       1000
# 44         4   1.0    0.0005        1      10000
# 45         4   1.0    0.0005        1      15000
# 46         4   2.0    0.0010        1       1000
# 47         4   2.0    0.0005        1      10000
# 48         4   2.0    0.0005        1      15000
# 49         4   3.0    0.0010        1       1000
# 50         4   3.0    0.0005        1      10000
# 51         4   3.0    0.0005        1      15000
# 52         4   4.0    0.0010        1       1000
# 53         4   4.0    0.0005        1      10000
# 54         4   5.0    0.0010        1       1000
# 55         4   5.0    0.0005        1      10000
# 56         4   6.0    0.0010        1       1000
# 57         4   6.0    0.0005        1      10000
# 58         4   7.0    0.0010        1       1000
# 59         4   7.0    0.0005        1      10000
# 60         4   8.0    0.0010        1       1000
# 61         4   8.0    0.0005        1       4000
# 62         4   9.0    0.0010        1       1000
# 63         4   9.0    0.0005        1       4000
# 64         4  10.0    0.0010        1       1000
# 65         4  10.0    0.0005        1       4000
# 66         4  15.0    0.0010        1       1000
# 67         4  20.0    0.0010        1       1000
# 68         4  50.0    0.0010        1       1000
# 69         4  70.0    0.0010        1       1000
# 70         5   1.0    0.0010        1       1000
# 71         5   1.0    0.0005        1      10000
# 72         5   1.0    0.0005        1      15000
# 73         5   2.0    0.0010        1       1000
# 74         5   2.0    0.0005        1      10000
# 75         5   2.0    0.0005        1      15000
# 76         5   3.0    0.0010        1       1000
# 77         5   3.0    0.0005        1      10000
# 78         5   3.0    0.0005        1      15000
# 79         5   4.0    0.0010        1       1000
# 80         5   4.0    0.0005        1      10000
# 81         5   4.0    0.0005        1      15000
# 82         5   5.0    0.0010        1       1000
# 83         5   5.0    0.0005        1      10000
# 84         5   5.0    0.0005        1      15000
# 85         5   6.0    0.0010        1       1000
# 86         5   6.0    0.0005        1      10000
# 87         5   7.0    0.0010        1       1000
# 88         5   7.0    0.0005        1      10000
# 89         5   8.0    0.0010        1       1000
# 90         5   8.0    0.0005        1      10000
# 91         5   9.0    0.0010        1       1000
# 92         5   9.0    0.0005        1      10000
# 93         5   9.0    0.0005        1      20000
# 94         5  10.0    0.0010        1       1000
# 95         5  10.0    0.0005        1       8000
# 96         5  12.0    0.0010        1       1000
# 97         5  12.0    0.0005        1       2000
# 98         5  15.0    0.0010        1       1000
# 99         5  15.0    0.0005        1       2000
# 100        5  18.0    0.0010        1       1000
# 101        5  18.0    0.0005        1       2000
# 102        5  20.0    0.0010        1       1000
# 103        5  20.0    0.0005        1       2000
# 104        5  50.0    0.0010        1       1000
# 105        5  50.0    0.0005        1       2000
# 106        5  70.0    0.0010        1       1000
# 107        5  70.0    0.0005        1       2000
# 108        6   1.0    0.0010        1       1000
# 109        6   1.0    0.0005        1      10000
# 110        6   2.0    0.0010        1       1000
# 111        6   2.0    0.0005        1      10000
# 112        6   3.0    0.0010        1       1000
# 113        6   3.0    0.0005        1      10000
# 114        6   4.0    0.0010        1       1000
# 115        6   4.0    0.0005        1      10000
# 116        6   5.0    0.0010        1       1000
# 117        6   5.0    0.0005        1      10000
# 118        6   5.0    0.0005        1      15000
# 119        6   6.0    0.0005        1      10000
# 120        6   6.0    0.0005        1      15000
# 121        6   7.0    0.0005        1      10000
# 122        6   7.0    0.0005        1      15000
# 123        6   8.0    0.0010        1       1000
# 124        6   8.0    0.0005        1      10000
# 125        6   8.0    0.0005        1      15000
# 126        6   9.0    0.0010        1       1000
# 127        6   9.0    0.0005        1      10000
# 128        6   9.0    0.0005        1      15000
# 129        6  10.0    0.0010        1       1000
# 130        6  10.0    0.0005        1      10000
# 131        6  12.0    0.0010        1       1000
# 132        6  12.0    0.0005        1      10000
# 133        6  14.0    0.0010        1       1000
# 134        6  14.0    0.0005        1       5000
# 135        6  14.0    0.0005        1      10000
# 136        6  15.0    0.0010        1       1000
# 137        6  15.0    0.0005        1       2000
# 138        6  18.0    0.0010        1       1000
# 139        6  18.0    0.0005        1       2000
# 140        6  20.0    0.0010        1       1000
# 141        6  20.0    0.0005        1       2000
# 142        6  50.0    0.0010        1       1000
# 143        6  50.0    0.0005        1       2000
# 144        6  70.0    0.0010        1       1000
# 145        6  70.0    0.0005        1       2000
# 146        7   5.0    0.0010        1       1000
# 147        7   5.0    0.0005        1      10000
# 148        7   8.0    0.0010        1       1000
# 149        7   8.0    0.0005        1      10000
# 150        7   9.0    0.0010        1       1000
# 151        7   9.0    0.0005        1      10000
# 152        7  10.0    0.0010        1       1000
# 153        7  10.0    0.0005        1      10000
# 154        7  12.0    0.0010        1       1000
# 155        7  12.0    0.0005        1      10000
# 156        7  14.0    0.0010        1       1000
# 157        7  14.0    0.0005        1       5000
# 158        7  14.0    0.0005        1      10000
# 159        7  15.0    0.0010        1       1000
# 160        7  15.0    0.0005        1       2000

# %%
import logging
root = logging.getLogger()
for handler in root.handlers[:]:
    root.removeHandler(handler)
logging.basicConfig(level=logging.DEBUG, filename='./data/dicke1_QSL_clusterjob.log')

# %%
# %doit -n 20 wait_for_optimization
# Out:
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T1
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T2
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T3
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T4
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T5
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T7
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T10
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T20
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T50
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_2nodes_T70
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T1
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T2
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T3
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T4
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T5
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T8
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T9
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T10
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T15
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T20
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T50
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_3nodes_T70
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T1
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T2
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T3
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T4
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T5
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T6
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T7
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T8
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T9
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T10
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T15
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T20
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T50
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T70
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T2
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T3
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T4
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T5
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T6
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T7
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T8
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T9
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T10
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T12
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T15
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T18
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T20
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T50
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T70
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T5
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T8
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T9
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T10
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T12
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T14
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T15
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T18
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T20
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T50
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T70
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T5
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T8
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T9
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T10
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T12
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T14
# -- create_runfolder:./data/dicke1_QSL_1traj/rf_7nodes_T15
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_4nodes_T0_50
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_5nodes_T1
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T1
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T2
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T3
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T4
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T6
# .  create_runfolder:./data/dicke1_QSL_1traj/rf_6nodes_T7
# .  update_runfolder:0
# .  update_runfolder:3
# .  update_runfolder:6
# .  update_runfolder:9
# .  update_runfolder:11
# .  update_runfolder:12
# .  update_runfolder:15
# .  update_runfolder:16
# .  update_runfolder:13
# .  update_runfolder:20
# .  update_runfolder:18
# .  update_runfolder:22
# .  update_runfolder:24
# .  update_runfolder:34
# .  update_runfolder:28
# .  update_runfolder:30
# .  update_runfolder:38
# .  update_runfolder:36
# .  update_runfolder:26
# .  update_runfolder:37
# .  update_runfolder:46
# .  update_runfolder:32
# .  update_runfolder:40
# .  update_runfolder:43
# .  update_runfolder:52
# .  update_runfolder:54
# .  update_runfolder:56
# .  update_runfolder:49
# .  update_runfolder:66
# .  update_runfolder:58
# .  update_runfolder:60
# .  update_runfolder:64
# .  update_runfolder:69
# .  update_runfolder:67
# .  update_runfolder:68
# .  update_runfolder:62
# .  update_runfolder:82
# .  update_runfolder:89
# .  update_runfolder:76
# .  update_runfolder:79
# .  update_runfolder:85
# .  update_runfolder:73
# .  update_runfolder:87
# .  update_runfolder:91
# .  update_runfolder:94
# .  update_runfolder:96
# .  update_runfolder:98
# .  update_runfolder:123
# .  update_runfolder:126
# .  update_runfolder:100
# .  update_runfolder:106
# .  update_runfolder:133
# .  update_runfolder:138
# .  update_runfolder:102
# .  update_runfolder:104
# .  update_runfolder:116
# .  update_runfolder:129
# .  update_runfolder:131
# .  update_runfolder:136
# -- submit_optimization:3
# -- submit_optimization:0
# -- submit_optimization:6
# -- submit_optimization:9
# -- submit_optimization:11
# -- submit_optimization:15
# -- submit_optimization:12
# -- submit_optimization:16
# -- submit_optimization:13
# -- submit_optimization:20
# -- submit_optimization:18
# -- submit_optimization:36
# -- submit_optimization:24
# -- submit_optimization:28
# -- submit_optimization:30
# -- submit_optimization:34
# -- submit_optimization:38
# -- submit_optimization:22
# -- submit_optimization:32
# -- submit_optimization:26
# -- submit_optimization:43
# -- submit_optimization:40
# -- submit_optimization:37
# -- submit_optimization:54
# -- submit_optimization:60
# -- submit_optimization:46
# -- submit_optimization:52
# -- submit_optimization:56
# -- submit_optimization:58
# -- submit_optimization:66
# -- submit_optimization:64
# -- submit_optimization:49
# -- submit_optimization:67
# -- submit_optimization:62
# -- submit_optimization:69
# -- submit_optimization:68
# -- submit_optimization:82
# -- submit_optimization:76
# -- submit_optimization:85
# -- submit_optimization:96
# -- submit_optimization:73
# -- submit_optimization:79
# -- submit_optimization:89
# -- submit_optimization:91
# -- submit_optimization:94
# -- submit_optimization:87
# -- submit_optimization:98
# -- submit_optimization:100
# -- submit_optimization:102
# -- submit_optimization:136
# -- submit_optimization:106
# -- submit_optimization:104
# -- submit_optimization:129
# -- submit_optimization:131
# -- submit_optimization:116
# -- submit_optimization:133
# -- submit_optimization:126
# -- submit_optimization:138
# .  update_runfolder:146
# .  update_runfolder:148
# .  update_runfolder:150
# .  update_runfolder:152
# .  update_runfolder:154
# .  update_runfolder:156
# .  update_runfolder:159
# .  update_runfolder:140
# .  update_runfolder:142
# .  update_runfolder:144
# .  wait_for_optimization:3
# .  wait_for_optimization:0
# .  wait_for_optimization:6
# .  wait_for_optimization:9
# .  wait_for_optimization:11
# .  wait_for_optimization:15
# .  wait_for_optimization:12
# .  wait_for_optimization:16
# .  wait_for_optimization:13
# .  wait_for_optimization:20
# .  wait_for_optimization:18
# .  wait_for_optimization:28
# .  wait_for_optimization:24
# .  wait_for_optimization:36
# .  wait_for_optimization:30
# .  wait_for_optimization:34
# .  wait_for_optimization:38
# .  wait_for_optimization:22
# .  wait_for_optimization:26
# .  wait_for_optimization:32
# .  wait_for_optimization:43
# .  wait_for_optimization:37
# .  wait_for_optimization:54
# .  wait_for_optimization:52
# .  wait_for_optimization:66
# .  wait_for_optimization:58
# .  wait_for_optimization:56
# .  wait_for_optimization:40
# .  wait_for_optimization:60
# .  wait_for_optimization:46
# .  wait_for_optimization:49
# .  wait_for_optimization:69
# .  wait_for_optimization:62
# .  wait_for_optimization:68
# .  wait_for_optimization:67
# .  wait_for_optimization:82
# .  wait_for_optimization:64
# .  wait_for_optimization:76
# .  wait_for_optimization:85
# .  wait_for_optimization:79
# .  wait_for_optimization:94
# .  wait_for_optimization:89
# .  wait_for_optimization:96
# .  wait_for_optimization:73
# .  wait_for_optimization:98
# .  wait_for_optimization:91
# .  wait_for_optimization:100
# .  wait_for_optimization:87
# -- submit_optimization:123
# -- submit_optimization:142
# -- submit_optimization:140
# -- submit_optimization:144
# -- submit_optimization:146
# -- submit_optimization:154
# -- submit_optimization:156
# -- submit_optimization:152
# -- submit_optimization:148
# -- submit_optimization:150
# -- submit_optimization:159
# .  wait_for_optimization:102
# .  wait_for_optimization:136
# .  wait_for_optimization:106
# .  wait_for_optimization:104
# .  wait_for_optimization:129
# .  wait_for_optimization:116
# .  wait_for_optimization:131
# .  wait_for_optimization:133
# .  wait_for_optimization:126
# .  wait_for_optimization:138
# .  update_runfolder:4
# .  update_runfolder:42
# .  update_runfolder:1
# .  update_runfolder:17
# .  update_runfolder:10
# .  update_runfolder:19
# .  update_runfolder:14
# .  update_runfolder:21
# .  update_runfolder:29
# .  update_runfolder:31
# .  update_runfolder:27
# .  update_runfolder:7
# .  update_runfolder:35
# .  update_runfolder:33
# .  update_runfolder:23
# .  update_runfolder:39
# .  update_runfolder:25
# .  update_runfolder:44
# .  update_runfolder:55
# .  update_runfolder:53
# .  update_runfolder:61
# .  update_runfolder:59
# .  update_runfolder:50
# .  update_runfolder:57
# .  update_runfolder:41
# .  update_runfolder:47
# .  update_runfolder:83
# .  update_runfolder:63
# .  update_runfolder:65
# .  update_runfolder:80
# .  update_runfolder:86
# .  update_runfolder:90
# .  update_runfolder:95
# .  update_runfolder:74
# .  update_runfolder:97
# .  update_runfolder:99
# .  update_runfolder:101
# .  wait_for_optimization:123
# .  update_runfolder:77
# .  wait_for_optimization:144
# .  wait_for_optimization:140
# .  wait_for_optimization:142
# .  wait_for_optimization:146
# .  wait_for_optimization:154
# .  wait_for_optimization:156
# .  wait_for_optimization:152
# .  wait_for_optimization:148
# .  wait_for_optimization:150
# .  wait_for_optimization:159
# .  update_runfolder:88
# .  update_runfolder:92
# .  update_runfolder:103
# .  update_runfolder:107
# .  update_runfolder:117
# .  update_runfolder:127
# .  update_runfolder:137
# .  update_runfolder:105
# .  update_runfolder:132
# .  update_runfolder:134
# -- submit_optimization:10
# -- submit_optimization:14
# -- submit_optimization:1
# -- submit_optimization:4
# .  update_runfolder:139
# -- submit_optimization:17
# -- submit_optimization:7
# -- submit_optimization:29
# -- submit_optimization:31
# -- submit_optimization:39
# -- submit_optimization:35
# -- submit_optimization:19
# -- submit_optimization:27
# -- submit_optimization:33
# -- submit_optimization:44
# -- submit_optimization:55
# -- submit_optimization:59
# -- submit_optimization:57
# -- submit_optimization:41
# -- submit_optimization:47
# -- submit_optimization:50
# -- submit_optimization:53
# -- submit_optimization:61
# -- submit_optimization:63
# -- submit_optimization:90
# -- submit_optimization:83
# -- submit_optimization:77
# -- submit_optimization:80
# -- submit_optimization:86
# -- submit_optimization:95
# -- submit_optimization:74
# -- submit_optimization:97
# -- submit_optimization:99
# -- submit_optimization:65
# -- submit_optimization:101
# .  update_runfolder:130
# .  submit_optimization:42
# .  submit_optimization:21
# -- submit_optimization:137
# -- submit_optimization:88
# .  submit_optimization:25
# .  submit_optimization:23
# .  update_runfolder:143
# .  update_runfolder:145
# .  update_runfolder:141
# .  update_runfolder:124
# .  update_runfolder:147
# .  update_runfolder:155
# .  update_runfolder:153
# .  update_runfolder:160
# .  update_runfolder:149
# -- submit_optimization:92
# -- submit_optimization:105
# -- submit_optimization:107
# .  wait_for_optimization:10
# .  wait_for_optimization:14
# -- submit_optimization:103
# .  wait_for_optimization:1
# .  wait_for_optimization:4
# .  wait_for_optimization:7
# .  wait_for_optimization:17
# .  wait_for_optimization:29
# .  wait_for_optimization:31
# .  wait_for_optimization:39
# .  wait_for_optimization:35
# .  wait_for_optimization:19
# .  wait_for_optimization:33
# .  wait_for_optimization:27
# .  wait_for_optimization:44
# .  wait_for_optimization:55
# .  wait_for_optimization:59
# .  wait_for_optimization:57
# .  wait_for_optimization:41
# .  wait_for_optimization:47
# .  wait_for_optimization:53
# .  wait_for_optimization:50
# .  wait_for_optimization:61
# .  wait_for_optimization:90
# .  wait_for_optimization:63
# -- submit_optimization:132
# -- submit_optimization:134
# -- submit_optimization:127
# -- submit_optimization:130
# -- submit_optimization:139
# .  wait_for_optimization:83
# .  wait_for_optimization:77
# .  wait_for_optimization:80
# .  wait_for_optimization:86
# .  wait_for_optimization:95
# .  wait_for_optimization:74
# .  wait_for_optimization:97
# -- submit_optimization:141
# -- submit_optimization:145
# .  wait_for_optimization:99
# .  wait_for_optimization:65
# .  wait_for_optimization:101
# -- submit_optimization:143
# -- submit_optimization:124
# .  submit_optimization:117
# .  update_runfolder:70
# .  wait_for_optimization:42
# .  wait_for_optimization:21
# .  wait_for_optimization:25
# .  wait_for_optimization:137
# .  wait_for_optimization:88
# .  wait_for_optimization:23
# .  wait_for_optimization:92
# .  submit_optimization:153
# .  submit_optimization:147
# .  wait_for_optimization:105
# .  submit_optimization:155
# .  submit_optimization:149
# .  wait_for_optimization:107
# .  wait_for_optimization:103
# .  submit_optimization:160
# .  update_runfolder:2
# .  update_runfolder:8
# .  update_runfolder:5
# .  update_runfolder:45
# .  update_runfolder:48
# .  wait_for_optimization:132
# .  wait_for_optimization:134
# .  wait_for_optimization:130
# .  wait_for_optimization:127
# .  wait_for_optimization:139
# .  update_runfolder:78
# .  wait_for_optimization:141
# .  update_runfolder:51
# .  wait_for_optimization:143
# .  update_runfolder:84
# .  wait_for_optimization:145
# .  update_runfolder:81
# .  update_runfolder:75
# .  wait_for_optimization:124
# .  wait_for_optimization:117
# .  submit_optimization:70
# .  wait_for_optimization:155
# .  wait_for_optimization:153
# .  wait_for_optimization:149
# .  update_runfolder:93
# .  submit_optimization:8
# .  submit_optimization:2
# .  update_runfolder:135
# .  submit_optimization:5
# .  update_runfolder:128
# .  submit_optimization:45
# .  wait_for_optimization:147
# .  submit_optimization:48
# .  wait_for_optimization:160
# .  update_runfolder:125
# .  submit_optimization:51
# .  submit_optimization:84
# .  submit_optimization:75
# .  submit_optimization:81
# .  submit_optimization:78
# .  submit_optimization:93
# .  wait_for_optimization:70
# -- submit_optimization:135
# .  wait_for_optimization:8
# .  wait_for_optimization:2
# .  submit_optimization:128
# .  wait_for_optimization:5
# .  wait_for_optimization:45
# .  submit_optimization:125
# .  wait_for_optimization:48
# .  wait_for_optimization:51
# .  wait_for_optimization:84
# .  wait_for_optimization:75
# .  wait_for_optimization:81
# .  wait_for_optimization:78
# .  wait_for_optimization:93
# .  wait_for_optimization:135
# .  update_runfolder:121
# .  update_runfolder:114
# .  wait_for_optimization:128
# .  update_runfolder:119
# .  update_runfolder:110
# .  wait_for_optimization:125
# .  update_runfolder:108
# .  update_runfolder:112
# .  submit_optimization:121
# .  submit_optimization:114
# .  submit_optimization:119
# .  submit_optimization:110
# .  submit_optimization:108
# .  submit_optimization:112
# .  wait_for_optimization:121
# .  wait_for_optimization:114
# .  wait_for_optimization:119
# .  wait_for_optimization:110
# .  wait_for_optimization:108
# .  wait_for_optimization:112
# .  update_runfolder:71
# .  update_runfolder:109
# .  update_runfolder:113
# .  submit_optimization:71
# .  submit_optimization:109
# .  submit_optimization:113
# .  wait_for_optimization:71
# .  wait_for_optimization:109
# .  wait_for_optimization:113
# .  update_runfolder:115
# .  submit_optimization:115
# .  wait_for_optimization:115
# .  update_runfolder:111
# .  submit_optimization:111
# .  wait_for_optimization:111
# .  update_runfolder:118
# .  submit_optimization:118
# .  wait_for_optimization:118
