# %% [markdown]
# # Dynamics from the Optimized Pulses

# %%
# %matplotlib inline

# %%
from src.doit_actions_v2 import run_traj_prop

# %%
from os.path import join

# %%
import pandas as pd

# %%
RF_ORIG = './data/method_comparison_dicke2/T5_rho_ntrajs1/'

# %%
run_traj_prop(
    RF_ORIG, n_trajs=1, n_procs=None, use_oct_pulses=True,
    config='config_rho')

# %%
qubit_pop = pd.read_fwf(
    join(RF_ORIG, 'qubit_pop.dat'), skiprows=1, comment='#', index_col=0)
qubit_pop.plot()

# %%
import matplotlib.pylab as plt

# %%
fig, ax = plt.subplots(figsize=(10, 6))
excitation = pd.read_fwf(
    join(RF_ORIG, 'excitation.dat'), skiprows=1, comment='#', index_col=0)
excitation.plot(fig=fig, ax=ax)

# %%
darkstate_cond = pd.read_fwf(
    join(RF_ORIG, 'darkstate_cond.dat'), skiprows=1, comment='#', index_col=0)
darkstate_cond.plot()

# %%
p_target = pd.read_fwf(
    join(RF_ORIG, 'P_target.dat'), skiprows=1, comment='#', index_col=0)
p_target.plot()
